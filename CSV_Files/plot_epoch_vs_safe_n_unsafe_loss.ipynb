# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Set the directory containing the CSV files
folder_path = './'

# Loop over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        
        # Read the CSV file
        data = pd.read_csv(file_path)
        
        # Check if the required columns exist
        if all(col in data.columns for col in ['epoch', 'unsafe_loss', 'safe_loss']):
            # Plotting
            # plt.figure()
            plt.figure(figsize=(6, 4))
            plt.plot(data['epoch'], data['unsafe_loss'], label='Unsafe Loss')
            plt.plot(data['epoch'], data['safe_loss'], label='Safe Loss')
            
            # Adding labels and title
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.title(filename.replace('.csv', ''))
            plt.legend()
            plt.grid(True)
            # Save the plot with the same name as the CSV file (without extension)
            # plt.savefig(os.path.join(folder_path, filename.replace('.csv', '.png')))
            
            # Show the plot (optional)
            plt.show()
            
            # Close the plot to free memory
            plt.close()
        else:
            print(f"File {filename} does not contain the required columns.")
